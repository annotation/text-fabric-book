# %% [markdown]
# # Pandas
#
# See [start](../basics/start.ipynb) for how to load corpora.
#
# Export a TF dataset as Pandas.
#
# See [usePandas](usePandas.ipynb) for how to work with this data in a Pandas dataframe.

# %%
from tf.app import use

# %%
A = use("annotation/mobydick:clone", checkout="clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mobydick/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mobydick/tf/0.1</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.0</a>, <a target="_blank" href="https://github.com/annotation/mobydick/blob/main/app" title="annotation/mobydick app">annotation/mobydick/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
c1 = F.otype.s("chunk")[1]
c1
# Out:
# 213961

# %%
A.plain(c1)
# Out:
# <div class=""><span class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.annotation.org/mobydick/TEI header/-2/&lt;3>&amp;version=0.1" title="Show this on the website" sec="TEI header@-2">TEI header@-2</a></span></span>  <span class="txtu"><span class=" is_meta">University </span></span><span class="txtu"><span class=" is_meta">of </span></span><span class="txtu"><span class=" is_meta">Oxford </span></span><span class="txtu"><span class=" is_meta">Text </span></span><span class="txtu"><span class=" is_meta">Archive </span></span><span class="txtu"><span class=" is_meta">Subject </span></span><span class="txtu"><span class=" is_meta">Headings</span></span><span class="txtu"><span class=" is_meta">Library </span></span><span class="txtu"><span class=" is_meta">of </span></span><span class="txtu"><span class=" is_meta">Congress </span></span><span class="txtu"><span class=" is_meta">Subject </span></span><span class="txtu"><span class=" is_meta">Headings
# ...

# %%
A.exportPandas(inTypes="")
# Out:
#   0.00s Create tsv file ...
#    |     0.15s   5%   10991 nodes written
#    |     0.29s  10%   21982 nodes written
#    |     0.42s  15%   32973 nodes written
#    |     0.56s  20%   43964 nodes written
#    |     0.70s  25%   54955 nodes written
#    |     0.84s  30%   65946 nodes written
#    |     0.98s  35%   76937 nodes written
#    |     1.12s  40%   87928 nodes written
#    |     1.26s  45%   98919 nodes written
#    |     1.39s  50%  109910 nodes written
#    |     1.53s  55%  120901 nodes written
#    |     1.67s  60%  131892 nodes written
#    |     1.81s  65%  142883 nodes written
#    |     1.95s  70%  153874 nodes written
#    |     2.09s  75%  164865 nodes written
#    |     2.22s  80%  175856 nodes written
#    |     2.36s  85%  186847 nodes written
#    |     2.50s  90%  197838 nodes written
#    |     2.64s  95%  208829 nodes written
#    |     2.77s 100%  219820 nodes written
#    |     2.77s 100%  219821 nodes written and done
# ...
